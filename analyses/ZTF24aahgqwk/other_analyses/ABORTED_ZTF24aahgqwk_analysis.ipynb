# %% [markdown]
# # ZTF24aahgqwk in NGC 3443
#
# ### Observation Notes
#
# Typically a session has 60 30-second exposures in each of r' and g', but starting with
# 2024-04-21, there are 120 of g', because g' images were getting fainter.
#
# [ZTF24aahgwk Observation Log](https://brianhill.github.io/supernova-observation/analyses/ZTF24aahgqwk/ZTF24aahgqwk_observation_log.html)

# %%
# THIS COMMENT IS THE LONGEST A LINE CAN BE AND STILL RENDER COMPLETELY WHEN PRINTING IN LANDSCAPE MODE.

import os

observations_directory = os.path.join(os.path.expanduser('~'), '2024 Sessions')
analysis_directory = os.path.join(os.path.expanduser('~'), 'ZTF24aahgqwk_analysis')

import math
import numpy as np
from astropy import units as u
from astropy.nddata import CCDData
from astropy.io import fits
from ccdproc import ImageFileCollection, combine, subtract_dark, flat_correct # Combiner
import astroalign as aa
import matplotlib.pyplot as plt
# %matplotlib inline

# filters

filters = ['g', 'r']
filter_full_names = ["Sloan g'", "Sloan r'"]

SLOAN_G_FILTER = 0
SLOAN_R_FILTER = 1

# exposure durations

light_exposure = 30 * u.second
flat_exposure = 0.1 * u.second
dark_exposure = light_exposure  # our method presumes this equality
bias_exposure = flat_exposure  # our method presumes this equality

# %% [markdown]
# ## Combine the Calibration Images into Masters
#
# ### Calibration Images
#
# The calibration images are in ~/2024 Sessions/2024-04-12/. In turn, ~/2024 Sessions is
# actually a soft link to /Volumes/Astronomy Data/2024 Sessions/2024 Sessions.

# %%
# the date on which the calibration images were taken

calibration_date = '2024-04-12'

# calibration directory

calibration_directory = os.path.join(observations_directory, calibration_date)

# subdirectory for the 30-second darks

dark_directory = os.path.join(calibration_directory, 'dark')

# subdirectories for the 0.1-second g and r flats

flat_directories_by_filter = {filter:os.path.join(calibration_directory, 'flat', filter)
                              for filter in filters}

# subdirectory for the biases (TheSky Professional Edition may indicate that these are 0.1-second darks)

bias_directory = os.path.join(calibration_directory, 'bias')

# darks

dark_files = ImageFileCollection(dark_directory).files_filtered(include_path='True')
darks = [trimmed_image_reader(file) for file in dark_files]

for dark in darks:
    confirm_fits_header(dark, (1381, 940), 30.0, 3, 0.0, 'dark')

# flats by filter

flat_files_by_filter = {filter:ImageFileCollection(flat_directory).files_filtered(include_path='True')
                        for filter, flat_directory in flat_directories_by_filter.items()}
flats_by_filter = {filter:[trimmed_image_reader(file) for file in flat_files]
                   for filter, flat_files in flat_files_by_filter.items()}

for filter, flats in flats_by_filter.items():
    for flat in flats:
        confirm_fits_header(flat, (1381, 940), 0.1, 3, 0.0, filter)

# biases

bias_files = ImageFileCollection(bias_directory).files_filtered(include_path='True')
biases = [trimmed_image_reader(file) for file in bias_files]

for bias in biases:
    confirm_fits_header(bias, (1381, 940), 0.1, 3, 0.0, 'dark')

# Combine darks, flats, and biases

calibration_combination_method = 'median'  # alternatively, the method can be 'average'

master_dark = combine(darks, method=calibration_combination_method)
master_flats_by_filter = {filter:combine(flats, method=calibration_combination_method)
                         for filter, flats in flats_by_filter.items()}
master_bias = combine(biases, method=calibration_combination_method)

# Perform dark subtraction of the master flats

master_flats_subtracted_by_filter = {filter:subtract_dark(master_flat,
                                                          master_bias,
                                                          data_exposure=flat_exposure,
                                                          dark_exposure=bias_exposure,
                                                          scale=False)
                                     for filter, master_flat in master_flats_by_filter.items()}
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412
from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227422 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227428 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227428 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227434 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227434 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227440 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227440 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227446 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227446 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227452 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227452 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227458 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227458 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227464 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227464 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227470 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227470 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227476 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227476 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227483 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227483 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227489 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227489 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227495 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227495 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227501 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227501 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227507 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227507 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227513 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227513 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227519 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227519 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227525 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227525 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227531 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227531 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227537 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227537 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227543 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227543 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227549 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227549 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227555 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227555 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227560 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227560 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227566 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227566 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227572 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227572 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227578 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227578 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227584 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227584 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227590 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227590 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227596 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227596 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227602 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227602 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227608 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227608 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227614 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227614 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227619 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227619 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227625 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227625 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227631 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227631 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227637 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227637 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227643 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227643 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227649 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227649 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227655 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227655 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227661 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227661 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227667 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227667 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227673 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227673 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227679 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227679 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227685 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227685 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227691 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227691 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227696 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.227696 from DATE-OBS'.
# ...
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234578 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234578 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234584 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234584 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234590 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234590 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234596 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234596 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234602 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234602 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234608 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234608 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234614 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234614 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234620 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234620 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234626 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234626 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234633 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234633 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234639 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234639 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234645 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234645 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234651 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234651 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234657 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234657 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234662 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234662 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234668 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234668 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234674 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234674 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234680 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234680 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234686 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234686 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234692 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234692 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234698 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234698 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234704 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234704 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234710 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234710 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234716 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234716 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234722 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234722 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234728 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234728 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234734 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234734 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234740 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234740 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234746 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234746 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234752 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234752 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234758 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234758 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234764 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234764 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234770 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234770 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234775 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234775 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234781 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234781 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234787 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234787 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234793 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234793 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234800 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234800 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234806 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234806 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234812 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234812 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234818 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234818 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234824 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234824 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234830 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234830 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234836 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234836 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234842 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234842 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234847 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234847 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234853 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234853 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234859 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234859 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234865 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234865 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234871 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234871 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234878 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234878 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234884 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234884 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234890 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234890 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234896 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234896 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234902 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234902 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234908 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234908 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234914 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234914 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234920 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234920 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234925 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234925 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234931 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234931 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234937 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234937 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234945 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234945 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234951 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234951 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234957 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234957 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234963 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234963 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234969 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234969 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234975 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234975 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234981 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234981 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234986 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234986 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234992 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60412.234992 from DATE-OBS'.
# INFO:astropy:splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes.
# INFO: splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes. [ccdproc.combiner]
# INFO:astropy:splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes.
# INFO: splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes. [ccdproc.combiner]
# INFO:astropy:splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes.
# INFO: splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes. [ccdproc.combiner]

# %% [markdown]
# ## Load and Calibrate Lights; Then Write Them
#
# What follows is a time-consuming loop, done once for each observation date.
#
# Because it is time-consuming, we write the results, so they can just be read back in for alignment.

# %%
observation_dates = [
    '2024-03-20',
    '2024-03-21',
    '2024-03-23',
    '2024-03-27',
    '2024-04-02',
    '2024-04-03',
    '2024-04-04',
    '2024-04-06',
    '2024-04-10',
    '2024-04-11',
    '2024-04-13',
    '2024-04-17',
    '2024-04-21',
    '2024-04-22',
    '2024-04-23',
    '2024-04-29',
    '2024-04-30',
    '2024-05-02'
]

# def hot_pixel_reject(image, sigma_multiple):
#     data = image.data
#     width, height = data.shape
#     with np.nditer(data, flags=['multi_index', 'buffered'], op_flags=['readwrite']) as it:
#         for x in it:
#             neighbors = 0.0
#             squares = 0.0
#             count = 0
#             i, j = it.multi_index
#             for ii in [i - 1, i, i + 1]:
#                 # check for out of bounds column index (and skip if necessary)
#                 if ii < 0 or ii >= width:
#                     continue
#                 for jj in [j - 1, j, j + 1]:
#                     # check for out of bounds row index (and skip if necessary)
#                     if jj < 0 or jj >= height:
#                         continue
#                     # check for self (and skip if necessary)
#                     if ii == i and jj == j:
#                         continue
#                     neighbor = data[ii, jj]
#                     neighbors += neighbor
#                     squares += neighbor * neighbor
#                     count += 1
#             neighbors = neighbors / count  # now neighbors is the mean of the neighbors
#             squares = squares / count # now squares is the mean of the squares
#             sigma = math.sqrt((squares - neighbors * neighbors) * count / (count - 1))
#             x[...] = neighbors if abs(x - neighbors) >= sigma_multiple * sigma else x
#     return image


for observation_date in observation_dates:
    
    # subdirectories for the 30-second g and r lights
    
    light_directories_by_filter = {
        filter:light_directory_for_filter(observation_date, filter)
        for filter in filters
    }
    
    # lights by filter
    
    light_files_by_filter = {
        filter:ImageFileCollection(light_directory).files_filtered(include_path='True')
        for filter, light_directory in light_directories_by_filter.items()
    }
    
    lights_by_filter = {
        filter:[trimmed_image_reader(file) for file in light_files]
        for filter, light_files in light_files_by_filter.items()
    }
    
    for filter, lights in lights_by_filter.items():
        for light in lights:
            confirm_fits_header(light, (1381, 940), 30.0, 3, 0.0, filter)
    
    subtracted_lights_by_filter = {
        filter:[subtract_dark(light,
                              master_dark,
                              data_exposure=light_exposure,
                              dark_exposure=dark_exposure,
                              scale=False) for light in lights]
        for filter, lights in lights_by_filter.items()
    }
    
    # Perform flat division
    
    calibrated_lights_by_filter = {
        filter:[flat_correct(light, master_flats_subtracted_by_filter[filter])
                for light in lights]
        for filter, lights in subtracted_lights_by_filter.items()
    }
    
    # The horizontal lines in CMOS output can be removed with median subtraction
    
    # Code would look something like:
    
    # calibrated_medians = [
    #     np.median(sample, axis=1, keepdims=True)
    #     for sample in sample_calibrated_data_list
    # ]
    
    # calibrated_subtracted = [
    #     sample_calibrated_data_list[i] - calibrated_medians[i]
    #     for i in range(len(filters))
    # ]
    
    # Before we align the lights we could try hot pixel rejection
    
    #     hp_rejected_lights_by_filter = {
    #         filter:[hot_pixel_reject(light, 5.0) for light in lights]
    #         for filter, lights in calibrated_lights_by_filter.items()
    #     }
    
    # write the calibrated lights
    
    calibrated_directories_by_filter = {
        filter:calibrated_directory_for_filter(observation_date, filter)
        for filter in filters
    }
    
    for calibrated_directory in calibrated_directories_by_filter.values():
        if not os.path.exists(calibrated_directory):
            os.makedirs(calibrated_directory)
    
    for filter, calibrated_directory in calibrated_directories_by_filter.items():
        lights = lights_by_filter[filter]
        light_files = light_files_by_filter[filter]
        calibrated_lights = calibrated_lights_by_filter[filter]
        for j in range(len(calibrated_lights)):
            # Then we write all the files for that filter
            light_header = lights[j].header
            calibrated_data = calibrated_lights[j]
            calibrated_file = os.path.join(calibrated_directory, os.path.basename(light_files[j]))
            calibrated_file2 = os.path.splitext(calibrated_file)[0] + '_calibrated.fit'
            fits.writeto(calibrated_file2, calibrated_data, light_header, overwrite=True)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275066 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275066 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381449.053 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483194.922 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851220.317 from OBSGEO-[LBH]'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381449.053 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483194.922 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851220.317 from OBSGEO-[LBH]'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275425 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275425 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275783 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275783 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276143 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276143 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276501 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276501 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276860 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276860 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277219 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277219 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277577 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277577 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277936 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277936 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.278295 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.
for observation_date in observation_dates:
    
    # read back in the calibrated lights
    
    calibrated_directories_by_filter = {
        filter:calibrated_directory_for_filter(observation_date, filter)
        for filter in filters
    }

    calibrated_lights_by_filter = {
        filter:[CCDData.read(file, unit=u.adu)
                for file in ImageFileCollection(calibrated_directory).files_filtered(include_path='True')]
        for filter, calibrated_directory in calibrated_directories_by_filter.items()
    }
    
    lights_aligned_with_footprints_by_filter = {
        filter:[
            # somewhat arbitrarily, we will use the image with index 10 as the reference light
            aa.register(light, calibrated_lights_by_filter[filter][10], detection_sigma=3.0)
            for light in lights
        ]
        for filter, lights in  calibrated_lights_by_filter.items()
    }
    
    # write the aligned lights
    
    aligned_directories_by_filter = {
        filter:aligned_directory_for_filter(observation_date, filter)
        for filter in filters
    }

    for filter in filters:
        lights = lights_by_filter[filter]
        light_files = light_files_by_filter[filter]
        lights_aligned_with_footprints = lights_aligned_with_footprints_by_filter[filter]
        aligned_directory = aligned_directories_by_filter[filter]
        for j in range(len(lights_aligned_with_footprints)):
            # Then we write all the files for that filter
            light_header = lights[j][0].header
            light_aligned_data = lights_aligned_with_footprints[j][0]
            aligned_file = os.path.join(aligned_directory, os.path.basename(light_files[j]))
            aligned_file2 = os.path.splitext(aligned_file)[0] + '_aligned.fit'
            fits.writeto(aligned_file2, light_aligned_data, light_header, overwrite=True)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275066 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275066 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381449.053 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483194.922 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851220.317 from OBSGEO-[LBH]'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381449.053 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483194.922 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851220.317 from OBSGEO-[LBH]'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275425 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275425 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275783 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.275783 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276143 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276143 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276501 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276501 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276860 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.276860 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277219 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277219 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277577 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277577 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277936 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.277936 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.278295 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.278295 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.278654 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.278654 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.279013 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.279013 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.279373 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.279373 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.279731 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.279731 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.280090 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.280090 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.280448 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.280448 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.280806 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.280806 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.281165 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.281165 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.281524 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.281524 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.281882 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.281882 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.282242 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.282242 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.282600 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.282600 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.282959 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.282959 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.283317 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.283317 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.283676 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.283676 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.284034 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.284034 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.284393 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.284393 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.284752 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.284752 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.285111 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.285111 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.285469 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.285469 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.285828 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.285828 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.286188 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.286188 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.286546 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.286546 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.286905 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.286905 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.287263 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.287263 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.287622 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.287622 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.287981 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.287981 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.288340 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.288340 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.288700 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.288700 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.289058 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.289058 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.289416 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.289416 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.289775 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.289775 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.290134 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.290134 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.290492 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.290492 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.290851 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.290851 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.291209 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.291209 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.291569 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.291569 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.291927 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.291927 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.292286 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.292286 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.292644 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.292644 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.293003 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.293003 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.293361 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.293361 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.293720 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.293720 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.294078 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.294078 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.294437 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.294437 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.294795 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.294795 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.295154 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.295154 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.295513 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.295513 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.295871 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.295871 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.296230 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.296230 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.253506 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.253506 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381449.053 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483194.922 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851220.317 from OBSGEO-[LBH]'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381449.053 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483194.922 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851220.317 from OBSGEO-[LBH]'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.253875 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.253875 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.254235 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.254235 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.254593 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.254593 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.254952 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.254952 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.255311 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.255311 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.255670 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.255670 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.256029 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.256029 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.256389 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.256389 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.256749 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.256749 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.257108 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.257108 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.257467 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.257467 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.257826 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.257826 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.258186 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.258186 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.258544 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.258544 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.258903 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.258903 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.259261 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.259261 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.259620 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.259620 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.259978 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.259978 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.260338 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.260338 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.260696 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.260696 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.261056 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.261056 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.261415 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.261415 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.261775 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.261775 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.262134 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.262134 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.262492 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.262492 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.262851 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.262851 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.263210 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.263210 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.263568 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.263568 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.263928 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.263928 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.264288 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.264288 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.264647 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.264647 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.265007 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.265007 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.265366 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.265366 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.265724 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.265724 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.266082 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.266082 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.266442 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.266442 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.266801 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.266801 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.267159 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.267159 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.267518 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.267518 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.267876 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.267876 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.268235 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.268235 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.268594 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.268594 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.268952 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.268952 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.269311 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.269311 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.269671 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.269671 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.270030 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.270030 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.270388 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.270388 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.270747 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.270747 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.271106 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.271106 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.271465 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.271465 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.271825 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.271825 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.272184 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.272184 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.272543 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.272543 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.272901 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.272901 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.273260 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.273260 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.273618 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.273618 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.273977 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.273977 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.274336 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.274336 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.274694 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60389.274694 from DATE-OBS'.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 62
#      51 calibrated_directories_by_filter = {
#      52     filter:calibrated_directory_for_filter(observation_date, filter)
#      53     for filter in filters
#      54 }
#      56 calibrated_lights_by_filter = {
#      57     filter:[CCDData.read(file, unit=u.adu)
#      58             for file in ImageFileCollection(calibrated_directory).files_filtered(include_path='True')]
#      59     for filter, calibrated_directory in calibrated_directories_by_filter.items()
#      60 }
# ---> 62 lights_aligned_with_footprints_by_filter = {
#      63     filter:[
#      64         # somewhat arbitrarily, we will use the image with index 10 as the reference light
#      65         aa.register(light, calibrated_lights_by_filter[filter][10], detection_sigma=3.0)
#      66         for light in lights
#      67     ]
#      68     for filter, lights in  calibrated_lights_by_filter.items()
#      69 }
#      71 # write the aligned lights
#      73 aligned_directories_by_filter = {
#      74     filter:aligned_directory_for_filter(observation_date, filter)
#      75     for filter in filters
#      76 }
#
# Cell In[9], line 63, in <dictcomp>(.0)
#      51 calibrated_directories_by_filter = {
#      52     filter:calibrated_directory_for_filter(observation_date, filter)
#      53     for filter in filters
#      54 }
#      56 calibrated_lights_by_filter = {
#      57     filter:[CCDData.read(file, unit=u.adu)
#      58             for file in ImageFileCollection(calibrated_directory).files_filtered(include_path='True')]
#      59     for filter, calibrated_directory in calibrated_directories_by_filter.items()
#      60 }
#      62 lights_aligned_with_footprints_by_filter = {
# ---> 63     filter:[
#      64         # somewhat arbitrarily, we will use the image with index 10 as the reference light
#      65         aa.register(light, calibrated_lights_by_filter[filter][10], detection_sigma=3.0)
#      66         for light in lights
#      67     ]
#      68     for filter, lights in  calibrated_lights_by_filter.items()
#      69 }
#      71 # write the aligned lights
#      73 aligned_directories_by_filter = {
#      74     filter:aligned_directory_for_filter(observation_date, filter)
#      75     for filter in filters
#      76 }
#
# Cell In[9], line 65, in <listcomp>(.0)
#      51 calibrated_directories_by_filter = {
#      52     filter:calibrated_directory_for_filter(observation_date, filter)
#      53     for filter in filters
#      54 }
#      56 calibrated_lights_by_filter = {
#      57     filter:[CCDData.read(file, unit=u.adu)
#      58             for file in ImageFileCollection(calibrated_directory).files_filtered(include_path='True')]
#      59     for filter, calibrated_directory in calibrated_directories_by_filter.items()
#      60 }
#      62 lights_aligned_with_footprints_by_filter = {
#      63     filter:[
#      64         # somewhat arbitrarily, we will use the image with index 10 as the reference light
# ---> 65         aa.register(light, calibrated_lights_by_filter[filter][10], detection_sigma=3.0)
#      66         for light in lights
#      67     ]
#      68     for filter, lights in  calibrated_lights_by_filter.items()
#      69 }
#      71 # write the aligned lights
#      73 aligned_directories_by_filter = {
#      74     filter:aligned_directory_for_filter(observation_date, filter)
#      75     for filter in filters
#      76 }
#
# File /Applications/Anaconda/anaconda3/envs/supernova/lib/python3.10/site-packages/astroalign.py:495, in register(source, target, fill_value, propagate_mask, max_control_points, detection_sigma, min_area)
#     463 """Transform ``source`` to coincide pixel to pixel with ``target``.
#     464
#     465 Args:
#    (...)
#     486
#     487 """
#     488 t, __ = find_transform(
#     489     source=source,
#     490     target=target,
#    (...)
#     493     min_area=min_area,
#     494 )
# --> 495 aligned_image, footprint = apply_transform(
#     496     t, source, target, fill_value, propagate_mask
#     497 )
#     498 return aligned_image, footprint
#
# File /Applications/Anaconda/anaconda3/envs/supernova/lib/python3.10/site-packages/astroalign.py:418, in apply_transform(transform, source, target, fill_value, propagate_mask)
#     415 source_data = _data(source)
#     416 target_shape = _data(target).shape
# --> 418 aligned_image = warp(
#     419     source_data,
#     420     inverse_map=transform.inverse,
#     421     output_shape=target_shape,
#     422     order=3,
#     423     mode="constant",
#     424     cval=_default_median(source_data),
#     425     clip=True,
#     426     preserve_range=True,
#     427 )
#     429 footprint = warp(
#     430     _np.zeros(_shape(source_data), dtype="float32"),
#     431     inverse_map=transform.inverse,
#     432     output_shape=target_shape,
#     433     cval=1.0,
#     434 )
#     435 footprint = footprint > 0.4
#
# File /Applications/Anaconda/anaconda3/envs/supernova/lib/python3.10/site-packages/skimage/transform/_warps.py:894, in warp(image, inverse_map, map_args, output_shape, order, mode, cval, clip, preserve_range)
#     892 ctype = 'float32_t' if image.dtype == np.float32 else 'float64_t'
#     893 if image.ndim == 2:
# --> 894     warped = _warp_fast[ctype](image, matrix,
#     895                                output_shape=output_shape,
#     896                                order=order, mode=mode, cval=cval)
#     897 elif image.ndim == 3:
#     898     dims = []
#
# File _warps_cy.pyx:71, in skimage.transform._warps_cy._warp_fast()
#
# ValueError: Big-endian buffer not supported on little-endian compiler

# %% [markdown]
# ## Re-Load and Stack the Lights
#
# What follows is a giant for loop, done once for each observation date.

# %%
for observation_date in []:
    
    # read back in the aligned lights
    
    aligned_directories_by_filter = {
        filter:aligned_directory_for_filter(observation_date, filter)
        for filter in filters
    }
    
    aligned_lights_by_filter = {
        filter:[CCDData.read(file, unit=u.adu)
                for file in ImageFileCollection(aligned_directory).files_filtered(include_path='True')]
        for filter, aligned_directory in aligned_directories_by_filter.items()
    }

    aligned_lights_by_filter = {
        filter:[CCDData.read(file, unit=u.adu)
                for file in ImageFileCollection(aligned_directory).files_filtered(include_path='True')]
        for filter, aligned_directory in aligned_directories_by_filter.items()
    }
    
    stacking_combination_method = 'average'  # alternatively, the method can be 'median'
    
    combined_lights_by_filter = {
        filter:combine(lights, method=stacking_combination_method)
        for filter, lights in aligned_lights_by_filter.items()
    }
    
    # create the directories where the stacked lights will be written

    stacked_directory = os.path.join(analysis_directory, 'stacked')

    if not os.path.exists(stacked_directory):
        os.makedirs(stacked_directory)

    # write the aligned lights

    for filter in filters:
        stacked_header = aligned_lights_by_filter[filter][0].header
        stacked_data = combined_lights_by_filter[filter]
        stacked_file = os.path.join(stacked_directory, observation_date + '-' + filter + '_stacked.fit')
        fits.writeto(stacked_file, stacked_data, stacked_header, overwrite=True)
