# %% [markdown]
# # RASA8 Test 2023-11-2425
#
# ### Overview
#
# At 20:36, we began taking and at 21:08 we stopped. This is 32 minutes.
#
# The exposures IDs go from 1896 to 2970 which is 1075 images.
#
# The exposure cadence is 1075 / (32 * 60) = 0.56 frames per second.
#
# Each image is 5.8MB.
#
# No calibration was performed and no filters were used.

# %% [markdown]
# ### Imports

# %%
# If you can get everything in this block of code to work, then likely that you have gotten
# all of your dependencies installed, and you can focus on getting actual code to work.

import os
import numpy as np
from astropy import units as u
from astropy.nddata import CCDData
from astropy.io import fits
from astropy.coordinates import SkyCoord
from ccdproc import ImageFileCollection, Combiner, combine, subtract_dark, flat_correct
import matplotlib.pyplot as plt
# %matplotlib inline
import astroalign as aa
import twirl

# Imports for Plate-Solving
from astropy.stats import mad_std
from photutils.detection import DAOStarFinder
from astroquery.astrometry_net import AstrometryNet
import keyring
# You will have to uncomment and execute the following (only once) with your actual astrometry.net API key:
# keyring.set_password('astroquery:astrometry_net', None, 'xxxxxxxxxxxxxxxx')
# Your key is then stored privately in the operating system's keychain. Then be sure to remove your key
# and comment back out the line. After doing those steps, the following should work:
AstrometryNet.api_key = keyring.get_password('astroquery:astrometry_net', None)

# %% [markdown]
# ### Load RASA Images

# %%
# Only the following group of constants should need to be adjusted, typically, from one analysis to the next.
observation_date = '2023-11-2425'
light_exposure = 1 * u.second
BINNING = 2  # 2X2 binning
SUBFRAMING = 1  # No Subframing
UNBINNED_PLATE_SCALE = 0.239
WIDTH_HEIGHT = (8288, 5644)
BINNED_SUBFRAMED_WIDTH_HEIGHT = tuple([x / BINNING / SUBFRAMING for x in WIDTH_HEIGHT])
plate_scale_raw = UNBINNED_PLATE_SCALE * BINNING
plate_scale = plate_scale_raw * u.arcsec
# Our sensor is spec'd as 8288x5644, but when binned 2x2 and half-subframed, it writes out 4 columns of NaNs.
# Therefore, we treat it as if it had 16 fewer columns, e.g., we treat it as if it was 8272x5644. This bins
# and subframes to 2068 columns and 1411 rows, or about 0.275x0.187 degrees. Only the larger dimension is used.
fov = np.max((8272, 5644)) / BINNING / SUBFRAMING * plate_scale.to(u.deg).value

# directories where the observation and calibration images being analyzed are kept
observation_directory = os.path.join(os.path.expanduser('~'), 'Sessions', observation_date)

# Log stretch utility

from math import log10, floor

def log_stretch_transform(black_point, saturation_range):
    
    log_saturation_range = log10(saturation_range)
    
    def fn(pixel_value):
        pixel_value -= black_point
        # The bizarre first conditional test on the next line avoids any attempt to transform NaNs.
        # if pixel_value != pixel_value or pixel_value <= 1.0:
        if pixel_value <= 1.0:
            return 0
        else:
            log_pixel_value = log10(pixel_value)
            if log_pixel_value >= log_saturation_range:
                return 255;
            else:
                return floor(256 * log_pixel_value / log_saturation_range)
        
    return fn

# Trimmed image reader utility (needed because our images have four columns of NaNs)

def delete_last_columns(arr, columns_to_delete):
    column_count = np.shape(arr)[1]
    del_arr = np.delete(arr, slice(column_count - columns_to_delete, column_count), 1)
    return del_arr

def trimmed_image_reader(file):
    img = CCDData.read(file, unit=u.adu)
    data = img.data
    trimmed_data = delete_last_columns(data, 4)
    img.data = trimmed_data
    return img

# %%
light_files = ImageFileCollection(observation_directory).files_filtered(include_path='True')
lights = [trimmed_image_reader(file) for file in light_files]

# the aligned directories are written to not read from
aligned_directory = os.path.join(observation_directory, 'aligned')

if not os.path.exists(aligned_directory):
    os.makedirs(aligned_directory)

# the CCDData.read command in the above spits out a gob of warnings which are annoying and not important
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150234 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150234 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381307.962 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483128.141 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851244.155 from OBSGEO-[LBH]'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381307.962 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483128.141 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851244.155 from OBSGEO-[LBH]'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150255 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150255 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150275 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150275 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150296 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150296 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150316 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150316 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150336 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150336 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150356 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150356 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150377 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150377 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150397 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150397 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150417 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150417 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150437 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150437 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150458 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150458 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150478 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150478 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150498 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150498 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150518 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150518 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150539 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150539 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150559 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150559 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150579 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150579 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150599 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150599 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150620 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150620 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150640 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150640 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150660 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150660 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150680 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150680 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150701 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150701 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150721 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150721 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150741 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150741 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150762 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150762 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150782 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150782 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150802 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150802 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150822 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150822 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150842 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150842 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150863 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150863 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150883 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150883 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150903 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150903 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150923 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150923 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150944 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150944 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150964 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150964 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150984 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.150984 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151005 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151005 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151025 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151025 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151045 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151045 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151065 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151065 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151085 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151085 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151106 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151106 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151126 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151126 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151147 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151147 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151167 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151167 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151187 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151187 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151207 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151207 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151227 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151227 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151248 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151248 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151268 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151268 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151288 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151288 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151309 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151309 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151329 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151329 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151349 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151349 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151369 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151369 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151390 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151390 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151410 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151410 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151430 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151430 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151451 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151451 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151472 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151472 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151492 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151492 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151512 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151512 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151532 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151532 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151553 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151553 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151573 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151573 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151593 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151593 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151614 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151614 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151634 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151634 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151654 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151654 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151674 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151674 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151695 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151695 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151715 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.151715 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152025 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152025 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152045 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152045 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152065 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152065 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152086 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152086 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152106 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152106 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152126 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152126 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152146 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152146 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152166 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152166 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152187 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152187 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152207 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152207 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152227 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152227 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152248 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152248 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152268 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152268 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152288 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152288 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152308 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152308 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152329 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152329 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152349 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152349 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152369 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152369 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152389 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152389 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152410 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152410 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152430 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152430 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152450 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152450 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152470 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152470 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152491 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152491 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152511 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152511 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152531 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152531 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152551 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152551 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152572 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152572 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152592 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152592 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152612 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152612 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152632 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152632 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152653 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152653 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152673 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152673 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152693 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152693 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152713 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152713 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152734 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152734 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152754 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152754 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152774 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152774 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152794 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152794 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152815 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152815 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152835 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152835 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152855 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152855 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152875 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152875 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152896 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152896 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152916 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152916 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152936 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152936 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152957 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152957 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152977 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152977 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152997 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.152997 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153017 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153017 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153038 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153038 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153058 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153058 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153078 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153078 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153098 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153098 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153119 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153119 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153139 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153139 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153159 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153159 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153179 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153179 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153200 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153200 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153220 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153220 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153240 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153240 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153260 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153260 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153280 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153280 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153301 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153301 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153321 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153321 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153341 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153341 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153362 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153362 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153382 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153382 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153402 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153402 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153423 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153423 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153443 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153443 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153463 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153463 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153484 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153484 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153504 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153504 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153524 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153524 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153544 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153544 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153565 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153565 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153585 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153585 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153605 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153605 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153625 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153625 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153645 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153645 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153666 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153666 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153686 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153686 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153706 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153706 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153726 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153726 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153747 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153747 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153767 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153767 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153787 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153787 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153807 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153807 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153828 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153828 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153848 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153848 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153868 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153868 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153888 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153888 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153909 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153909 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153929 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153929 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153949 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153949 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153969 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153969 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153990 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.153990 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154010 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154010 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154030 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154030 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154051 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154051 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154071 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154071 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154091 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154091 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154111 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154111 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154131 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154131 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154152 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154152 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154172 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154172 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154192 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154192 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154213 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154213 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154233 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154233 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154253 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154253 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154273 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154273 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154294 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154294 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154314 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154314 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154334 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154334 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154354 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154354 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154375 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154375 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154395 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154395 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154415 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154415 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154435 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154435 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154456 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154456 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154476 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154476 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154496 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154496 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154516 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154516 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154537 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154537 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154557 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154557 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154577 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154577 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154597 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154597 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154618 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154618 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154638 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154638 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154658 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154658 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154679 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154679 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154699 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154699 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154719 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154719 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154739 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154739 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154760 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154760 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154780 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154780 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154800 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154800 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154820 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154820 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154840 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.154840 from DATE-OBS'.
# ...
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170892 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170892 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170912 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170912 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170932 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170932 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170953 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170953 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170973 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170973 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170993 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.170993 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171013 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171013 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171034 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171034 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171054 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171054 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171074 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171074 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171094 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171094 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171115 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171115 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171135 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171135 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171155 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171155 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171175 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171175 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171195 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171195 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171216 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171216 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171236 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171236 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171257 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171257 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171278 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171278 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171298 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171298 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171318 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171318 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171338 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171338 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171359 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171359 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171379 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171379 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171399 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171399 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171421 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171421 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171441 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171441 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171462 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171462 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171483 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171483 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171504 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171504 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171524 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171524 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171545 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171545 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171565 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171565 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171585 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171585 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171606 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171606 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171626 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171626 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171646 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171646 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171667 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171667 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171687 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171687 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171707 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171707 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171728 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171728 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171749 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171749 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171770 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171770 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171791 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171791 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171812 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171812 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171832 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171832 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171852 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171852 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171873 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171873 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171893 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171893 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171913 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171913 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171933 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171933 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171954 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171954 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171974 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171974 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171995 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.171995 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172015 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172015 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172037 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172037 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172057 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172057 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172077 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172077 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172098 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172098 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172118 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172118 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172139 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172139 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172159 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172159 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172179 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172179 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172200 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172200 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172220 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172220 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172240 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172240 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172260 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172260 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172281 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172281 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172301 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172301 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172321 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172321 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172343 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astroquery:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60273.172343 from DATE-OBS'.

# %% [markdown]
# ### Examine Images

# %%
# First grab a sample light

sample_light = lights[100]
sample_data = np.asarray(sample_light)

# Median subtract each row to get rid of background

medians = np.median(sample_light, axis=1, keepdims=True)
subtracted = sample_light - medians

# %%
# Log stretch uncalibrated

stretch_function = log_stretch_transform(7, 50)
transform = np.vectorize(stretch_function)
transformed_sample_light = transform(subtracted)

# %%
# Display sample

fig, axes = plt.subplots(1, 1, figsize=(10, 10))

axes.imshow(sample_light, cmap='gray')
axes.set_title("Sample Uncalibrated Light")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create and Write the Aligned Lights
#
# Before combining we have to do alignment

# %%
reference_light_list = [lights_calibrated[0] for lights_calibrated in lights_calibrated_list]

lights_aligned_with_footprints_list = [[aa.register(l, reference_light_list[i], detection_sigma=3.0) for
                                        l in lights_calibrated_list[i]] for i in range(len(filters))]

# %%
first_header_list = []

for i in range(len(filters)):
    # First we pick out all the stuff for a given filter
    lights = lights_list[i]
    light_files = light_files_list[i]
    lights_aligned_with_footprints = lights_aligned_with_footprints_list[i]
    aligned_directory = aligned_directory_list[i]
    for j in range(len(lights_aligned_with_footprints)):
        # Then we write all the files for that filter
        light_header = lights[j][0].header
        light_aligned_data = lights_aligned_with_footprints[j][0]
        aligned_file = os.path.join(aligned_directory, os.path.basename(light_files[j]))
        aligned_file2 = os.path.splitext(aligned_file)[0] + '_aligned.fit'
        fits.writeto(aligned_file2, light_aligned_data, light_header, overwrite=True)
    first_header_list.append(lights[0][0].header)

# %% [markdown]
# ### Read Back in and Stack the Lights

# %%
# we'll have to do this for each filter, so make some empty lists to append to
first_light_list = []  # this contains the whole first fits file for each filter
combined_light_list = []  # this contains the combined light data for each filter

for i in range(len(filters)):
    aligned_directory = aligned_directory_list[i]
    aligned_files = ImageFileCollection(aligned_directory).files_filtered(include_path='True')
    first_light_list.append(fits.open(aligned_files[0]))
    lights = [CCDData.read(file, unit=u.adu) for file in aligned_files]
    combined_light_list.append(combine(lights, method=method))
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.108034 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.108034 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381433.687 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483197.997 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851226.198 from OBSGEO-[LBH]'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381433.687 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483197.997 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851226.198 from OBSGEO-[LBH]'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.110304 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.110304 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.112562 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.112562 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.114819 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.114819 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.117076 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.117076 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.119334 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.119334 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.121592 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.121592 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.123849 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.123849 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.126107 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.126107 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.128365 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.128365 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.130622 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.130622 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.132880 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.132880 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.135138 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.135138 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.137396 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.137396 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.139654 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.139654 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.141912 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.141912 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.144170 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.144170 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.146428 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.146428 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.148687 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.148687 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.150943 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.150943 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.153202 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.153202 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.155460 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.155460 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.157717 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.157717 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.159975 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.159975 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.162232 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.162232 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.164489 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.164489 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.166758 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.166758 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.169027 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.169027 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.171296 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.171296 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.173566 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.173566 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.108788 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.108788 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381433.687 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483197.997 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851226.198 from OBSGEO-[LBH]'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -2381433.687 from OBSGEO-[LBH].
# Set OBSGEO-Y to -4483197.997 from OBSGEO-[LBH].
# Set OBSGEO-Z to  3851226.198 from OBSGEO-[LBH]'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.111045 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.111045 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.113303 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.113303 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.115560 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.115560 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.117817 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.117817 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.120075 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.120075 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.122333 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.122333 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.124590 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.124590 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.126848 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.126848 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.129106 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.129106 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.131363 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.131363 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.133621 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.133621 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.135879 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.135879 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.138137 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.138137 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.140395 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.140395 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.142653 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.142653 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.144911 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.144911 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.147169 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.147169 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.149427 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.149427 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.151685 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.151685 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.153943 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.153943 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.156200 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.156200 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.158458 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.158458 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.160716 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.160716 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.162973 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.162973 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.165242 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.165242 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.167511 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.167511 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.169780 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.169780 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.172049 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.172049 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.174307 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59928.174307 from DATE-OBS'.

# %% [markdown]
# ### Examine the Stacked Lights

# %%
stacked_data_list = [np.asarray(combined_light) for combined_light in combined_light_list]

# Median subtract

medians_list = [np.median(stacked_data, axis=1, keepdims=True) for stacked_data in stacked_data_list]
stacked_subtracted_list = [stacked_data_list[i] - medians_list[i] for i in range(len(filters))]

# Log stretch

stretch_function3 = log_stretch_transform(0, 100)
transform3 = np.vectorize(stretch_function3)
transformed_stacked_subtracted_list = [[transform3(data) for data in stacked_subtracted]
                                       for stacked_subtracted in stacked_subtracted_list]

# %%
# Stacked Sloan g' Image

fig, axes = plt.subplots(1, 1, figsize=(8, 6))

axes.imshow(transformed_stacked_subtracted_list[SLOAN_G_FILTER], cmap='gray')

axes.set_title("Stacked Lights - " + filter_full_names[SLOAN_G_FILTER])

plt.tight_layout()
plt.show()

# %%
# Stacked Sloan r' Image

fig, axes = plt.subplots(1, 1, figsize=(8, 6))

axes.imshow(transformed_stacked_subtracted_list[SLOAN_R_FILTER], cmap='gray')

axes.set_title("Stacked Lights - " + filter_full_names[SLOAN_R_FILTER])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plate-Solve and Write the Stacked Images
#
# I tried to follow the twirl package directions for plate solving ([example notebook](https://github.com/lgrcia/twirl/blob/master/docs/notebooks/example.ipynb))
# but got an error I couldn't sort out at
#
# ```
# gaias = twirl.gaia_radecs(center, fov/2, limit=20)
# ```
#
# I'm guessing an API key is needed and without it gaias just comes back as an empty list.
#
# In our first-generation notebooks, we used DAOStarFinder, so let's return to that, and then
# try the astrometry.net interface for plate-solving.
#
# #### Get Sources with DAOStarFinder then Plate-Solve with AstrometryNet
#
# We are following the [AstrometryNet](https://astroquery.readthedocs.io/en/latest/astrometry_net/astrometry_net.html)
# documentation.

# %%
bkg_sigma_list = [mad_std(stacked_data) for stacked_data in stacked_data_list]
daofind = DAOStarFinder(fwhm=4., threshold=5. * bkg_sigma, brightest=100)
sources_list = [daofind(stacked_data) for stacked_data in stacked_data_list]

for sources in sources_list:
    sources.sort('flux')
    sources.reverse()

sources_list[SLOAN_G_FILTER]
# Out:
# <QTable length=100>
#   id      xcentroid          ycentroid      ...        peak               flux                mag
# int64      float64            float64       ...      float64            float64             float64
# ----- ------------------ ------------------ ... ------------------ ------------------ --------------------
#     1 251.49717479083907   298.754477137936 ...  37819.47008950389 1080.7033120964397   -7.584266206195778
#     2 246.80060124245674   301.853843217138 ... 22120.801316849313 353.78964378434927   -6.371862789967768
#     3 1458.9779368889522  826.5383867931948 ... 1807.7879072455603 55.075496275775826   -4.352396047982337
#     4  899.2957529140987  797.5269158785804 ... 1451.4186424411423     45.57149884329   -4.146733281828368
#     5 1165.0583892542109 466.08486434013747 ...  869.0652009495948 29.760635792788122   -3.684105512610513
#     6  1204.939530509824 123.62996987991328 ...  912.7272325443255 28.333135005597104   -3.630736577521025
#     7  910.4183369321782  306.8764248961821 ...   797.472588808987  24.23864937588399   -3.461271041113636
#     8 1557.6210579178749  964.4950591982883 ...  711.5331445502454 22.958837224604082  -3.4023747224109058
#     9 1549.0515394938893 1275.9395921034568 ...  715.1870620699071   21.3884500784898   -3.325448286025863
#    10 1786.4010864764514  891.4879239429857 ...  713.5557354672703  21.32444390199719  -3.3221942861823672
#    11 1557.5906304684888  965.0124836734782 ...  714.2659467049663  20.97276645783695  -3.3041393019775125
#    12 380.10893707612485 158.69233911496462 ... 449.03673367063914 13.959745149167079  -2.8621937245644284
#    13  690.3717032748337 132.23064088118855 ...  363.9703337761971 11.201506732920896  -2.6231911106445094
#    14 1946.4176472453075 1263.9611520911044 ...  330.2433751407044 10.160220924551522  -2.5172578784500916
#    15 340.11966915558867  386.0988176143146 ... 271.31526548071446  8.595468817122837  -2.3356739227836316
#    16  1728.550587910819 1141.2182036408146 ... 199.72085646699145 6.1437475643498995  -1.9710834075073194
#    17 1881.1771049611646 1405.3341561900224 ...  201.2551478645865 6.1269501817250935  -1.9681108727370784
#    18  772.9243807307324 25.272120629926984 ... 186.62596440489142 5.9473711569441825   -1.935812605783651
#    19 1683.2676360414393  65.04822047121576 ...  185.7841160963278  5.337958167063408  -1.8184379148779197
#   ...                ...                ... ...                ...                ...                  ...
#    81 450.21155403483704 1395.9555688219896 ...  15.57119305907749  1.353980604760606 -0.32903110824029247
#    82 1787.2446707593645 1246.9411492227114 ... 42.299649195195315 1.3529182966928077  -0.3281789254059737
#    83  711.4484972336857 143.80593413434667 ...  48.55956273512263 1.3409578649255909 -0.31853782956971305
#    84  1380.489237266484  1340.118849553424 ... 43.104617132295616 1.3245254128458115  -0.3051507381286662
#    85 1899.9746464549794    79.604117233511 ...  40.85113297783914  1.319562284352455 -0.30107473518173167
#    86  585.3394197300411 1065.4418782066389 ... 31.226747409497506 1.2925070130352125  -0.2785822705449914
#    87  396.4735308151801 335.79728940020254 ...  46.46160783070262 1.2796746279048783  -0.2677488982047026
#    88 1256.7914874602527  1.207136736137164 ...  11.90356499614152 1.2759698083495925 -0.26460099587215075
#    89 378.41187952793365 17.205337588642987 ... 57.212605794100924  1.258737856692978  -0.2498382346307597
#    90  1226.254502806607 1232.0538024677148 ... 37.152562807696626 1.2562418518504308 -0.24768314470669017
#    91 62.753274100636084 241.09291820361025 ... 39.246794443672144 1.2272440632161539  -0.2223273497018171
#    92  277.0491590800635 1206.8595076980891 ...  48.23147226888511  1.212622864142935  -0.2093143816208147
#    93   1779.90592940988  1216.870261544903 ... 14.375597585178063 1.2122123029141403  -0.2089467185312257
#    94 225.82353049674427  774.5661641740054 ... 16.078700958009254 1.2079465707659487 -0.20511931308304943
#    95  1380.806652034939  1339.574029120759 ...  38.24379398263867 1.2017094595424327 -0.19949869959585448
#    96 1110.0652275872437  1158.843385622105 ... 36.090537566048695 1.1931846145981353 -0.19176911189642878
#    97 1393.2118117753919  37.12449388143401 ...  49.37560646016205 1.1902101136345458 -0.18905909074408195
#    98  1562.094006699488  1408.755482281976 ... 13.290118019536589 1.1878414916089688 -0.18689622805991263
#    99  1105.291832737881  414.7678724117143 ... 14.587658116251657 1.1767959202585272 -0.17675288525152139
#   100 1676.9100856075843  782.9447590478737 ... 12.535657538840631 1.1702921042494039 -0.17073568733621367

# %%
astrometry_net_settings = {
    'scale_units': 'arcsecperpix',
    'scale_type': 'ul',
    'scale_lower': 0.9 * plate_scale_raw,
    'scale_upper': 1.1 * plate_scale_raw,
    'solve_timeout': 120
}

wcs_header_list = [AstrometryNet.solve_from_source_list(sources['xcentroid'],
                                                        sources['ycentroid'],
                                                        BINNED_SUBFRAMED_WIDTH_HEIGHT[0],
                                                        BINNED_SUBFRAMED_WIDTH_HEIGHT[1],
                                                        **astrometry_net_settings) for sources in sources_list]
# Out:
# Solving.......Solving....

# %%
# Finally, we write out plate-solved files
stacked_file_list = [os.path.join(observation_directory, "stacked-" + filter + ".fits") for filter in filters]

for i in range(len(filters)):
    stacked_data = stacked_data_list[i]
    representative_header = first_header_list[i]
    wcs_header = wcs_header_list[i]
    representative_header.extend(wcs_header)
    stacked_file = stacked_file_list[i]
    fits.writeto(stacked_file, stacked_data, wcs_header, overwrite=True)

# %% [markdown]
# ### Then Use PSF Photometry to Determine Relative Magnitudes of Target and Reference Stars
#
# NB: In the files just written, the WCS header (for a given filter) was merged with the *first* FITS
# header (for a given filter). This is suspect and needs correcting/augmenting, because the total exposure
# duration and the MIDOBS are just those of the first image (for a given filter). If we in fact have 30 60-second
# images, taken over the course of say, 70 minutes, the MIDOBS should be 35 minutes later. Other things
# (like the data type) will no longer be correct (because calibrating and stacking changed the data type).
#
# There is a [Python package](https://photutils.readthedocs.io/en/stable/psf.html) for PSF photometry. Challenges in photometry are to be expected because targets are generally superimposed directly on galaxies of comparable magnitude. We imagine four strategies from which the required artistry in photometry will emerge:
#
# 1. Ordinary PSF photometry
# 2. PSF photometry with a fitted gradient background
# 3. PSF photometry by subtracting PanSTARRS images of the host galaxies (scaled to the plate-scale of our telescope, and possibly convolved to model our seeing)
# 4. PSF photometry one to two months after the supernovae have achieved peak brightness, using our images of the essentially-bare galaxies as background
#
# For background estimation, we should study [Building EPSF](https://photutils.readthedocs.io/en/stable/epsf.html#build-epsf) functions.
